# %%
from PIL import Image
import cv2 as cv
import matplotlib.pyplot as plt

from edge_detector import CannyEdgeDetector, PILEdgeDetector

# %%
test_image_path = "/home/ubuntu/dad/roboflow-100-benchmark/rf100/apples-fvpl5/valid/damaged_apple--40-_jpg.rf.09d67d19fc6eae82fe2dcdf9322bcdb9.jpg"

# %%
im = Image.open(test_image_path)
plt.imshow(im)

# %%
pil_edge_detector = PILEdgeDetector()
im1 = pil_edge_detector.detect(im=im,modes=["CONTOUR",])
plt.imshow(im1)

# %%
img = cv.imread(test_image_path)
img = cv.cvtColor(img, cv.COLOR_RGB2BGR)
plt.imshow(img)
plt.show()

# %%
canny_edge_detector = CannyEdgeDetector()
img1 = canny_edge_detector.detect(img=img,low=300,high=500)
plt.imshow(img1, cmap='Greys')
plt.show()
